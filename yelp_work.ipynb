# %%
import tarfile
tar = tarfile.open('yelp.tar')
tar.extractall('./yelp_folder')
tar.close()
print("Extraction done")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c9adab3e9681> in <module>
#       1 import tarfile
#       2 tar = tarfile.open('yelp.tar')
# ----> 3 tar.extractall('./yelp_folder')
#       4 tar.close()
#       5 print("Extraction done")
#
# C:\ProgramData\Anaconda3\lib\tarfile.py in extractall(self, path, members, numeric_owner)
#    2000             # Do not set_attrs directories, as we will do that further down
#    2001             self.extract(tarinfo, path, set_attrs=not tarinfo.isdir(),
# -> 2002                          numeric_owner=numeric_owner)
#    2003
#    2004         # Reverse sort directories.
#
# C:\ProgramData\Anaconda3\lib\tarfile.py in extract(self, member, path, set_attrs, numeric_owner)
#    2042             self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2043                                  set_attrs=set_attrs,
# ...
